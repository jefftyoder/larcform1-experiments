# %% [markdown]
# # clw sensitivity test #1 — analysis
#
# Protocol: `lf1e-clw-sensitivity-experiment-1.md`. Converts each variation's ClimaAtmos
# output to Pithan2016 format via `scripts/convert_to_pithan.py`, compares against
# `EC-Earth.nc`, builds the threshold/comparison tables, and plots profiles + time series.

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

REPO_ROOT = Path.cwd().resolve().parents[1]
sys.path.insert(0, str(REPO_ROOT / "scripts"))
import convert_to_pithan as ctp

figdir = Path("figures")
figdir.mkdir(exist_ok=True)

EXPERIMENT_DIR = REPO_ROOT / "experiments" / "clw sensitivity experiments"
VARIATION_OUTPUT_ROOT = EXPERIMENT_DIR / "output" / "lf1e-clw-1"
PITHAN_FORMAT_DIR = EXPERIMENT_DIR / "output" / "pithan_format"
EC_EARTH_PATH = REPO_ROOT / "Pithan 2016 Intercomparison Data" / "EC-Earth.nc"

SUFFIX = "1h_average"  # larcform1_1M_prognostic_edmfx.yml diagnoses everything at period: 1hours
CLW_THRESHOLD_KGKG = 1e-4  # 0.1 g/kg, Validation step 1
ANALYSIS_DAYS = 2

PITHAN_FORMAT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 1. Discover variation output directories
#
# Each variation lives under `output/lf1e-clw-1/v<N>_<name>/output_active/` (standalone
# `ci_driver.jl` runs — files sit directly in the output dir, no `clima_atmos/` subdir).

# %%
def discover_variations(root: Path) -> dict[str, Path]:
    """Map variation name (e.g. 'v2_0M') -> its output_active dir."""
    variations = {}
    if not root.exists():
        return variations
    for child in sorted(root.iterdir()):
        active = child / "output_active"
        if active.exists():
            variations[child.name] = active
    return variations


variations = discover_variations(VARIATION_OUTPUT_ROOT)
print(f"Found {len(variations)} variation(s) under {VARIATION_OUTPUT_ROOT}")
for name, path in variations.items():
    print(f"  {name}: {path}")
# Out:
# Found 11 variation(s) under /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1
#   v10_tdepice: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v10_tdepice/output_active
#   v11_noicedep: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v11_noicedep/output_active
#   v12_subltime1e9: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v12_subltime1e9/output_active
#   v1_base: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v1_base/output_active
#   v2_0M: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v2_0M/output_active
#   v4_cloudonly: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v4_cloudonly/output_active
#   v5_subltime10: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v5_subltime10/output_active
#   v6_subltime400: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v6_subltime400/output_active
#   v7_subltime1000: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v7_subltime1000/output_active
#   v8_subltime10000: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v8_subltime10000/output_active
#   v9_condtime10: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v9_condtime10/output_active

# %% [markdown]
# ## 2. Convert each variation to Pithan2016 format
#
# Reuses `scripts/convert_to_pithan.py::convert`, which already renames ClimaAtmos
# variables into EC-Earth's naming convention (`hus`→`q`, `ta`→`t`, `pfull`→`p`,
# `hur`→`rh`, `lwp`→`clwvi`, derives `precr` from `pr − prsn`) and fixes sign conventions.
# Passing `--suffix`/`SUFFIX` explicitly since the script's default (`3h_average`) doesn't
# match our `1hours` diagnostic period.

# %%
ctp._SUFFIX = SUFFIX

# Failure modes documented per the protocol (they land in the threshold table's notes)
KNOWN_FAILURE_NOTES = {
    "v3_2M": "setup error: 2M microphysics + SGS quadrature cloud not implemented "
    "(ClimaAtmos microphysics_wrappers.jl:609 'Not implemented yet')",
}

converted_paths = {}
failed_variations = {}
for name, nc_dir in variations.items():
    # A run that failed before writing diagnostics leaves an empty output_active/;
    # convert() sys.exit()s on those, so skip and record instead.
    if not any(nc_dir.glob(f"*_{SUFFIX}.nc")):
        failed_variations[name] = KNOWN_FAILURE_NOTES.get(
            name, "no diagnostic output — run failed before writing (see batch log)"
        )
        print(f"SKIP {name}: no *_{SUFFIX}.nc files in {nc_dir}")
        continue
    out_path = PITHAN_FORMAT_DIR / f"{name}.nc"
    ctp.convert(nc_dir, model_name=name, out_path=out_path)
    converted_paths[name] = out_path
# Out:
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v10_tdepice/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v10_tdepice.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v11_noicedep/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v11_noicedep.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v12_subltime1e9/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v12_subltime1e9.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v1_base/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v1_base.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v2_0M/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    iwp → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   SKIP  prsn (not found)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v2_0M.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v4_cloudonly/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v4_cloudonly.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v5_subltime10/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v5_subltime10.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v6_subltime400/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v6_subltime400.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v7_subltime1000/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v7_subltime1000.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v8_subltime10000/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
#
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v8_subltime10000.nc  (48 timesteps, 90 levels)
# Reading from: /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/lf1e-clw-1/v9_condtime10/output_active
#   3D    ta → t  shape=(48, 90)
#   3D    pfull → p  shape=(48, 90)
#   3D    hus → q  shape=(48, 90)
#   3D    hur → rh  shape=(48, 90)
#   3D    ua → u  shape=(48, 90)
#   3D    va → v  shape=(48, 90)
#   3D    clw → clw  shape=(48, 90)
#   3D    cli → cli  shape=(48, 90)
#   3D    cl → cl  shape=(48, 90)
#   1D    ts → ts  shape=(48,)
#   1D    rlds → rlds  shape=(48,)
#   1D    rlus → rlus (sign-flipped)  shape=(48,)
#   1D    rlut → rlut (sign-flipped)  shape=(48,)
#   1D    hfls → hl (sign-flipped)  shape=(48,)
#   1D    hfss → hs (sign-flipped)  shape=(48,)
#   1D    clivi → clivi  shape=(48,)
#   1D    lwp → clwvi  shape=(48,)
#   1D    prsn → precs (sign-flipped)  shape=(48,)
#   1D    pr - prsn → precr (sign-flipped)  shape=(48,)
#   1D    rhoa·hus·dz → prw  shape=(48,)
#   1D    cl → clt (max-random overlap)  shape=(48,)
# Wrote /Users/jeff/clima/larcform1-experiments/experiments/clw sensitivity experiments/output/pithan_format/v9_condtime10.nc  (48 timesteps, 90 levels)

# %% [markdown]
# ## 3. Load EC-Earth reference data
#
# Sanity-check the `clw`/`cli` units before trusting comparisons — EC-Earth labels them
# dimensionless (`"1"`); confirm the magnitude matches ClimaAtmos's kg/kg mixing ratios
# rather than some other normalization. Also confirm `ps` (and thus `p(nlev)`) is
# time-invariant, which is what lets us regrid onto a single fixed pressure grid instead of
# per-timestep.

# %%
ec_earth = xr.open_dataset(EC_EARTH_PATH, decode_times=False)

ps_range = (float(ec_earth["ps"].min()), float(ec_earth["ps"].max()))
print(f"EC-Earth ps range: {ps_range} Pa (expect constant -> fixed pressure grid)")

print(f"EC-Earth clw range: {float(ec_earth['clw'].min()):.3e} to {float(ec_earth['clw'].max()):.3e}")
print(f"EC-Earth cli range: {float(ec_earth['cli'].min()):.3e} to {float(ec_earth['cli'].max()):.3e}")

# Fixed pressure grid (single time slice; p(nlev) does not vary in time for EC-Earth)
ec_earth_p = ec_earth["p"].isel(time=0).values
print(f"EC-Earth pressure levels: {ec_earth_p.min():.1f} to {ec_earth_p.max():.1f} Pa, {len(ec_earth_p)} levels")
# Out:
# EC-Earth ps range: (101300.0, 101300.0) Pa (expect constant -> fixed pressure grid)
# EC-Earth clw range: -7.100e-28 to 6.809e-04
# EC-Earth cli range: 0.000e+00 to 3.604e-05
# EC-Earth pressure levels: 10.0 to 101180.0 Pa, 60 levels

# %% [markdown]
# ## 4. Pressure regrid helper
#
# ClimaAtmos's `lev` coordinate (from the converter) is z-height, not pressure, and its
# stretched grid doesn't line up level-for-level with EC-Earth's `nlev`. Both sides carry
# their own `p(time, lev)`, so interpolate profile variables onto EC-Earth's fixed pressure
# grid using each timestep's own `p` before comparing.

# %%
def regrid_to_pressure(ds: xr.Dataset, var: str, target_p: np.ndarray) -> xr.DataArray:
    """Interpolate ds[var] (time, lev) from its own p(time, lev) onto target_p (Pa).

    target_p must be ascending or descending consistently with ds['p'] per timestep.
    Returns a (time, plev) DataArray.
    """
    da = ds[var]
    p = ds["p"]
    n_time = da.sizes["time"]
    out = np.empty((n_time, len(target_p)))
    for t in range(n_time):
        p_t = p.isel(time=t).values
        v_t = da.isel(time=t).values
        order = np.argsort(p_t)
        out[t, :] = np.interp(target_p, p_t[order], v_t[order])
    return xr.DataArray(
        out,
        dims=("time", "plev"),
        coords={"time": da.coords["time"], "plev": target_p},
        attrs=da.attrs,
    )


def restrict_to_first_n_days(ds: xr.Dataset, n_days: int = ANALYSIS_DAYS) -> xr.Dataset:
    """Both converted ClimaAtmos files and EC-Earth use seconds-since-start time."""
    cutoff = n_days * 86400
    return ds.sel(time=ds["time"] <= cutoff)

# %% [markdown]
# ## 5. Check tables

# %%
def clw_threshold_row(name: str, path: Path) -> dict:
    # load_dataset (not open_dataset): reads into memory and closes the file, so
    # re-running the section-2 convert loop can overwrite these files without
    # hitting HDF5 locks from this kernel's cached handles.
    ds = restrict_to_first_n_days(xr.load_dataset(path, decode_times=False))
    max_clw = float(ds["clw"].max())
    return {
        "variation": name,
        "max_clw_kgkg": max_clw,
        "passes_threshold": max_clw > CLW_THRESHOLD_KGKG,
        "notes": "",
    }


threshold_rows = [clw_threshold_row(name, path) for name, path in converted_paths.items()]
# Failed runs stay in the table with their failure mode in notes (protocol: don't
# silently exclude them).
threshold_rows += [
    {"variation": name, "max_clw_kgkg": np.nan, "passes_threshold": False, "notes": note}
    for name, note in failed_variations.items()
]
threshold_table = pd.DataFrame(
    threshold_rows, columns=["variation", "max_clw_kgkg", "passes_threshold", "notes"]
)
if threshold_table.empty:
    print("No converted variations yet -- run the variations and re-execute from cell 2.")
else:
    threshold_table = threshold_table.sort_values("variation")
threshold_table
# Out:
#            variation  max_clw_kgkg  passes_threshold notes
# 0        v10_tdepice      0.000510              True
# 1       v11_noicedep      0.000511              True
# 2    v12_subltime1e9      0.000510              True
# 3            v1_base      0.000000             False
# 4              v2_0M      0.000141              True
# 5       v4_cloudonly      0.000000             False
# 6      v5_subltime10      0.000000             False
# 7     v6_subltime400      0.000000             False
# 8    v7_subltime1000      0.000000             False
# 9   v8_subltime10000      0.000480              True
# 10     v9_condtime10      0.000000             False

# %%
# Extended comparison table (Validation steps 2-8) — only for variations passing step 1
PROFILE_COMPARISON_VARS = ["cli", "q", "rh"]
SURFACE_COMPARISON_VARS = ["clwvi", "clivi", "precr", "precs"]


def mean_bias(a: np.ndarray, b: np.ndarray) -> float:
    return float(np.nanmean(a - b))


def rmse(a: np.ndarray, b: np.ndarray) -> float:
    return float(np.sqrt(np.nanmean((a - b) ** 2)))


def comparison_row(name: str, path: Path, ec_earth_10d: xr.Dataset, target_p: np.ndarray) -> dict:
    # load_dataset (not open_dataset) so no file handle stays cached in the kernel
    ds = restrict_to_first_n_days(xr.load_dataset(path, decode_times=False))
    row = {"variation": name}
    for var in PROFILE_COMPARISON_VARS:
        model_p = regrid_to_pressure(ds, var, target_p)
        ref_p = regrid_to_pressure(ec_earth_10d, var, target_p)
        row[f"{var}_bias"] = mean_bias(model_p.values, ref_p.values.mean(axis=0, keepdims=True))
        row[f"{var}_rmse"] = rmse(model_p.values, ref_p.values.mean(axis=0, keepdims=True))
    for var in SURFACE_COMPARISON_VARS:
        # 0M runs have no prsn diagnostic, so their converted files lack precr/precs
        if var not in ds:
            row[f"{var}_bias"] = np.nan
            row[f"{var}_rmse"] = np.nan
            continue
        model_v = ds[var].values
        ref_v = ec_earth_10d[var].values
        n = min(len(model_v), len(ref_v))
        row[f"{var}_bias"] = mean_bias(model_v[:n], ref_v[:n])
        row[f"{var}_rmse"] = rmse(model_v[:n], ref_v[:n])
    return row


passing = [] if threshold_table.empty else threshold_table.loc[threshold_table["passes_threshold"], "variation"].tolist()
ec_earth_10d = restrict_to_first_n_days(ec_earth)

comparison_rows = [
    comparison_row(name, converted_paths[name], ec_earth_10d, ec_earth_p) for name in passing
]
comparison_table = pd.DataFrame(comparison_rows)
if comparison_table.empty:
    print("No variations passed the clw threshold yet (or none have been run).")
comparison_table
# Out:
#           variation      cli_bias  cli_rmse    q_bias    q_rmse   rh_bias  \
# 0       v10_tdepice -1.248905e-06  0.000003  0.000025  0.000228  0.210466
# 1      v11_noicedep -1.442493e-06  0.000004  0.000031  0.000224  0.210354
# 2   v12_subltime1e9 -1.442233e-06  0.000004  0.000031  0.000224  0.210361
# 3             v2_0M -3.639824e-07  0.000003 -0.000004  0.000239  0.211211
# 4  v8_subltime10000 -1.366905e-06  0.000004  0.000010  0.000254  0.191106
#
#     rh_rmse  clwvi_bias  clwvi_rmse  clivi_bias  clivi_rmse  precr_bias  \
# 0  0.287355    0.075238    0.105586   -0.006339    0.008648    0.000004
# 1  0.287240    0.090446    0.127617   -0.007389    0.010119    0.000005
# 2  0.287249    0.090136    0.127024   -0.007385    0.010113    0.000005
# 3  0.287835   -0.026160    0.027915   -0.001577    0.004176         NaN
# 4  0.290845   -0.028734    0.037170   -0.005902    0.008436    0.000001
#
#    precr_rmse  precs_bias  precs_rmse
# 0    0.000005   -0.000005    0.000005
# 1    0.000006   -0.000007    0.000007
# 2    0.000006   -0.000007    0.000007
# 3         NaN         NaN         NaN
# 4    0.000003   -0.000003    0.000003

# %% [markdown]
# ## 6. Profile plots — day-1 time evolution, small multiples
#
# One grid per variable (`t`, `q`, `rh`, `clw`, `cli`): one box per source (each
# variation, plus EC-Earth as its own box), each box showing pressure-vs-value profiles
# at 2-hour intervals across day 1 (12 profiles: 0h, 2h, ..., 22h). EC-Earth gets its own
# panel rather than being overlaid into every variation's box — comparison is by
# pattern-matching panels, which also shows whether a variation's cloud-formation
# *timing* matches EC-Earth's, not just its mean level.
#
# Color follows the dataviz-skill sequential rule: one hue, light→dark, for the
# continuous "hours since start" quantity — a shared colorbar, not a 12-entry legend.

# %%
import math
import re
import matplotlib.colors as mcolors

DAY1_HOURS = list(range(0, 24, 2))  # 0h, 2h, ..., 22h -- 12 profiles


def nearest_time_indices(ds: xr.Dataset, hours: list[int]) -> list[int]:
    """Index of the time step nearest to each hour (time coord is seconds since start)."""
    time_hours = ds["time"].values / 3600.0
    return [int(np.argmin(np.abs(time_hours - h))) for h in hours]


def load_converted(name: str) -> xr.Dataset:
    # load_dataset (not open_dataset) so no file handle stays cached in the kernel
    return xr.load_dataset(converted_paths[name], decode_times=False)


def variation_number(name: str) -> int:
    """Sort by variation number so v2 comes before v10 (string sort puts v10 first)."""
    return int(re.match(r"v(\d+)", name).group(1))


def ordered_panel_names() -> list[str]:
    """Panel order: EC-Earth reference first, then passing variations, then
    non-passing, each group sorted by variation number."""
    passing_set = set(passing)
    return (
        ["EC-Earth"]
        + sorted((n for n in converted_paths if n in passing_set), key=variation_number)
        + sorted((n for n in converted_paths if n not in passing_set), key=variation_number)
    )


def plot_day1_evolution_grid(var: str, target_p: np.ndarray, hours: list[int] = DAY1_HOURS):
    """Small multiples: one box per source (EC-Earth, then passing variations, then
    non-passing), each box showing `var` profiles at 2-hour intervals across day 1,
    colored light->dark by hour."""
    sources = {
        name: (ec_earth if name == "EC-Earth" else load_converted(name))
        for name in ordered_panel_names()
    }

    n = len(sources)
    ncols = min(5, n)
    nrows = math.ceil(n / ncols)
    fig, axes = plt.subplots(
        nrows, ncols, figsize=(3.2 * ncols, 5 * nrows), sharex=True, sharey=True, squeeze=False
    )
    axes = axes.flatten()

    cmap = plt.get_cmap("Blues")
    norm = mcolors.Normalize(vmin=min(hours), vmax=max(hours))

    for ax, (name, ds) in zip(axes, sources.items()):
        idxs = nearest_time_indices(ds, hours)
        profile_all = regrid_to_pressure(ds, var, target_p)
        for h, idx in zip(hours, idxs):
            ax.plot(profile_all.isel(time=idx).values, target_p / 100.0, color=cmap(norm(h)), linewidth=1.5)
        ax.set_title(name if name == "EC-Earth" or name not in passing else f"{name} ✓", fontsize=10)

    for ax in axes[n:]:
        ax.set_visible(False)

    axes[0].invert_yaxis()
    bottom_row_start = (nrows - 1) * ncols
    for i in range(bottom_row_start, n):
        axes[i].set_xlabel(ec_earth[var].attrs.get("units", ""))
    for i in range(0, n, ncols):
        axes[i].set_ylabel("Pressure (hPa)")

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    fig.colorbar(sm, ax=axes[:n].tolist(), label="Hours since start", shrink=0.6)
    fig.suptitle(f"Day-1 profile evolution: {var} (✓ = passes clw threshold)")
    return fig


for var in ["t", "q", "rh", "clw", "cli"]:
    plot_day1_evolution_grid(var, ec_earth_p)
    fig = plt.gcf()
    fig.savefig(figdir / f"clw_sensitivity_{var}_profile.png", dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7. Time-series plots
#
# Column-integrated / scalar diagnostics over the first `ANALYSIS_DAYS` days.

# %%
TIMESERIES_PLOT_VARS = ["clwvi", "clivi", "precr", "precs"]

# Same ordering as the profile grids: EC-Earth first (plotted directly below), then
# passing variations by variation number.
passing_sorted = sorted(passing, key=variation_number)

# Fixed color per variation: panels that skip a variation (0M has no precr/precs)
# would otherwise restart the per-axis color cycle and mislabel curves vs the legend.
prop_cycle = plt.rcParams["axes.prop_cycle"].by_key()["color"]
variation_colors = {name: prop_cycle[i % len(prop_cycle)] for i, name in enumerate(passing_sorted)}

fig, axes = plt.subplots(len(TIMESERIES_PLOT_VARS), 1, figsize=(10, 3 * len(TIMESERIES_PLOT_VARS)), sharex=True)

for ax, var in zip(axes, TIMESERIES_PLOT_VARS):
    ax.plot(ec_earth_10d["time"] / 86400.0, ec_earth_10d[var], label="EC-Earth", color="black", linewidth=2)
    for name in passing_sorted:
        # load_dataset (not open_dataset) so no file handle stays cached in the kernel
        ds = restrict_to_first_n_days(xr.load_dataset(converted_paths[name], decode_times=False))
        if var not in ds:  # 0M runs lack precr/precs
            continue
        ax.plot(ds["time"] / 86400.0, ds[var], label=name, color=variation_colors[name], alpha=0.8)
    ax.set_ylabel(f"{var} ({ec_earth[var].attrs.get('units', '')})")

axes[-1].set_xlabel("Day")
axes[0].legend(loc="upper left", bbox_to_anchor=(1.02, 1.0))
fig.suptitle(f"{ANALYSIS_DAYS}-day time series: ClimaAtmos variations vs EC-Earth")
fig.tight_layout()
fig.savefig(figdir / f"clw_sensitivity_timeseries.png", dpi=150, bbox_inches="tight")
